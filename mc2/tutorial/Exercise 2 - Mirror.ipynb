# %% [markdown]
# #  Starting the server
#
# (Click [here](./Exercise 1.ipynb) if you want to go back to the previous notebook.)
#
# We'll first need to start the server to launch the enclave and to begin listening for client requests. However, since someone else on the team has been designated the enclave server, you won't need to do anything for this step. Below is a copy of the code that the enclave server is running to launch the enclave and listen for requests.

# %% [markdown]
# ```python
# from Utils import *
#
# # TODO: fill out `clients`
#
# ###########################################################
# # `clients` is a Python list, e.g.
# #
# # clients = ["alice", "bob"]
# ###########################################################
# clients = # ...
# start_server(clients)
# ```

# %% [markdown]
# Once the enclave server has been launched, move to the next [notebook](./Exercise 3.ipynb).
